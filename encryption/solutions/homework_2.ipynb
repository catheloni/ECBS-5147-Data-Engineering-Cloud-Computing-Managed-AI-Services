# %%
len("/workspaces/ECBS-5147-Data-Engineering-Cloud-Computing-Managed-AI-Services/encryption/solutions/cathelonis_keypair")
# Out:
# 114

# %%
len("/workspaces/ECBS-5147-Data-Engineering-Cloud-Computing-Managed-AI-Services/encryption/solutions/cathelonis_keypair")

# %%
ssh -i /workspaces/ECBS-5147-Data-Engineering-Cloud-Computing-Managed-AI-Services/encryption/solutions/cathelonis_keypair ubuntu@3.252.82.210
