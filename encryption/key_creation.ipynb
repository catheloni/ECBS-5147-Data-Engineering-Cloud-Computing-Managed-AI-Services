# %%
from pathlib import Path
from Crypto.Cipher import PKCS1_OAEP
from Crypto.PublicKey import RSA

# %%
def find_project_root():
    current = Path.cwd()
    # Try current directory first
    if (current / "ceu_key").exists():
        return current
    # Try parent directory
    if (current.parent / "ceu_key").exists():
        return current.parent
    # Try two levels up (for nested structures)
    if (current.parent.parent / "ceu_key").exists():
        return current.parent.parent
    return current  # Default to current if not found

# %%
PROJECT_FOLDER = find_project_root()
print(f"Looking for keypairs in folder: {PROJECT_FOLDER}")

PRIVATE_KEY_FILE = PROJECT_FOLDER / "ceu_key"
PUBLIC_KEY_FILE = PROJECT_FOLDER / "ceu_key.pub"

assert PRIVATE_KEY_FILE.exists(), f"Private key not found at {PRIVATE_KEY_FILE}. CWD: {Path.cwd()}"
assert PUBLIC_KEY_FILE.exists(), f"Public key not found at {PUBLIC_KEY_FILE}"

print(f"✓ Found private key: {PRIVATE_KEY_FILE}")
print(f"✓ Found public key: {PUBLIC_KEY_FILE}")
# Out:
# Looking for keypairs in folder: /workspaces/ECBS-5147-Data-Engineering-Cloud-Computing-Managed-AI-Services/encryption
# ✓ Found private key: /workspaces/ECBS-5147-Data-Engineering-Cloud-Computing-Managed-AI-Services/encryption/ceu_key
# ✓ Found public key: /workspaces/ECBS-5147-Data-Engineering-Cloud-Computing-Managed-AI-Services/encryption/ceu_key.pub

# %%
with open(PRIVATE_KEY_FILE, "r", encoding="utf8") as key_file:
    private_key = RSA.import_key(key_file.read())

public_key = private_key.publickey()
print(f"Public key:\n{public_key.export_key().decode('utf-8')}")
# Out:
# Public key:
# -----BEGIN PUBLIC KEY-----
# MIIBojANBgkqhkiG9w0BAQEFAAOCAY8AMIIBigKCAYEAorPb7gE7NwRHRzaPpf0k
# 4sQXFYdpIQz5C7zc+4/Keihk3TLaEDiTSrVH3+n1TmP5gEBRHjuBqoQkqRhOUcuT
# RSM2XYT85mFj81N3o8q1Nkr6Vhf/zP8427YDusNECBMgr3FNZlY+DDG75nigS6Ic
# 1BlCYPlbnjj/1Fpo2e4U7l/xsBWVa8QfijVmfRsOmnAguYMWIOIolqDg+azOE6yJ
# palER578K2rmuKyHkTDWoQ9PF2/MIwqWm9wWN6JOP43txM51CI9c/73Rpuszgl7C
# LiDir9AlZO/CPIUs4zPNb1eIu+x9f8etm/HrcJ8Kv9B2zrbPv0s9onkTMsPPUhOF
# urmSjBruSQ3f5vgusYqpj5vwOVKJIvtcr0B9Zuk2Oh7IQcNLDXepmfKJDrJ/JZmV
# OxL0EKSyfagpoJe/++g88uIbuajLdqZuxfbOerS873G3/fFblodI/a6Hf49rzvr2
# XxbK66IsaG1io7AzvYfXgDZcZ6pXKdMJoksVKizpNF6rAgMBAAE=
# -----END PUBLIC KEY-----

# %%
with open(PRIVATE_KEY_FILE, "r", encoding="utf8") as key_file:
    private_key = RSA.import_key(key_file.read())

print(f"Public key:\n{private_key.export_key().decode('utf-8')}")
# /j6UCvGWILLtQZsfGX1bfM7PuECSWZ9AGhF9sXkgPUU7FOyWve8HgGkDpKbFg8o6
# HONadt0e15LLfVwuZ9YrNXcRtkjDJE+lH0bJHws0igZHWm/5NjeVJP5bKC5nqwJz
# hwZe1oU8rV+Vzs4O/azo+AiOLRUf7CzhysHn8QsCgcBF1D7OyxWxnHS1iwLtoVdM
# 31zE/HMvHo3DlJ6MP4jn9Ben/a7cPz6HTuI9IeqOIX+UfpMXpEQT6m2PKbDtmAHP
# Q709U3wDtHVr7qjrk0ntDLy43uVKUMtzWmsbsXN7dYotwWyB9Mk7FebWNdu3XAdv
# dVV2bqUmYQ9m1gw0bo6rUoXa06qyay8Cl4bLL7deqBjKInWwf7zeYn/8RhIElCBI
# l6on6RNp3JtaA+0734lX6NiJeGtslpYC48rFY4Mq1wECgcEAq/cSw3ZD6JOpCOdw
# q51Sz1mzbecf4rp00sjitCgmBgbLBatGfi62ip3qOt/4nvxJJDM7TS51FgN0e/6a
# 68XYeWBIPnEW4nytIydng3wqQicR5u+Jyook6t1kciBJbKxD+qiZysOK6bC2UV6w
# LaVak1dnhEMJFyX4+flmG9cKvnU6ixMrjMyWpHjlHReR/6GtycM3sMyohO66L9CD
# bKN27F4Y0Q9ENFRLB2bSRSX/i2fYevAs0bqr3c0bLbHHLgI5AoHALpKm26YhxPQ9
# o3l+ExKqKpHBuzRLJyU6cNkv4uudW5x5UoHrb0v0UOqcF8zPIMvNr6G4Jkn95ybH
# GHTQGqhu31SxFB0FLzLY9cjP5xOy0PNAQNYKzN5mSMGjNF0yWpN2cg+mwHRA/095
# kvxS2OyJIv5OnhKzo3iy1dVVkQBq3v5eksCtpoGjwu7IS0im6mUpOYOz+KpDVf0J
# entcWr1Eo0CH0DrN7mfni01iTh8G/DVo4gpu+zTMAzwIzCGdEz0F
# -----END RSA PRIVATE KEY-----

# %%
# receiving an encrypted message:

# define encrypted message path
ENCRYPTED_MESSAGE_FILE = PROJECT_FOLDER / "encrypted_message.bin"

# %%
with open(ENCRYPTED_MESSAGE_FILE, "rb") as f:
    encrypted_message_from_file = f.read()

# %%
private_key_cipher = PKCS1_OAEP.new(private_key)

decrypted_message = private_key_cipher.decrypt(encrypted_message_from_file)
print(f"Decrypted message: {decrypted_message.decode('utf-8')}")
# Out:
# Decrypted message: Dear CEU, this is the visitor

# %%
PROJECT_FOLDER = find_project_root()
print(f"Looking for keypairs in folder: {PROJECT_FOLDER}")

PRIVATE_KEY_FILE = PROJECT_FOLDER / "ceu_key"
PUBLIC_KEY_FILE = PROJECT_FOLDER / "ceu_key.pub"

assert PRIVATE_KEY_FILE.exists(), f"Private key not found at {PRIVATE_KEY_FILE}. CWD: {Path.cwd()}"
assert PUBLIC_KEY_FILE.exists(), f"Public key not found at {PUBLIC_KEY_FILE}"

print(f"✓ Found private key: {PRIVATE_KEY_FILE}")
print(f"✓ Found public key: {PUBLIC_KEY_FILE}")
